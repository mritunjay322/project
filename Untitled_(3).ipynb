# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\MRITUNJAY\Desktop\EXL.csv")
# Out:
# C:\Users\MRITUNJAY\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (31,32,33,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df=df.replace({'date':['-']},'',regex=True)
df
# Out:
#          countyFIPS  stateFIPS      date  confirmed_cases  deaths  \
# 0              1001          1  22012020                0       0
# 1              1003          1  22012020                0       0
# 2              1005          1  22012020                0       0
# 3              1007          1  22012020                0       0
# 4              1009          1  22012020                0       0
# ...             ...        ...       ...              ...     ...
# 1048570       26105         26  20122020              890      15
# 1048571       26107         26  20122020             1568      12
# 1048572       26109         26  20122020             1571      23
# 1048573       26111         26  20122020             3697      36
# 1048574       26113         26  20122020              405       8
#
#          google_mobility_retail_and_recreation  \
# 0                                          NaN
# 1                                          NaN
# ...

# %%
df.isnull().sum().head(60)
# Out:
# countyFIPS                                                         0
# stateFIPS                                                          0
# date                                                               0
# confirmed_cases                                                    0
# deaths                                                             0
# google_mobility_retail_and_recreation                         612456
# google_mobility_grocery_and_pharmacy                          666890
# google_mobility_parks                                         982458
# google_mobility_transit_stations                              860704
# google_mobility_workplaces                                    342711
# google_mobility_residential                                   722806
# apple_mobility_driving                                        422931
# apple_mobility_transit                                       1125000
# apple_mobility_walking                                       1036500
# ...

# %%
df.describe()
# Out:
#          countyFIPS     stateFIPS  confirmed_cases        deaths  \
# count  1.179375e+06  1.179375e+06     1.179375e+06  1.179375e+06
# mean   3.035730e+04  3.026518e+01     2.016216e+03  4.852388e+01
# std    1.517704e+04  1.514963e+01     1.119552e+04  2.867077e+02
# min    1.000000e+00  1.000000e+00     0.000000e+00 -1.000000e+00
# 25%    1.817300e+04  1.800000e+01     4.000000e+00  0.000000e+00
# 50%    2.917300e+04  2.900000e+01     1.330000e+02  2.000000e+00
# 75%    4.507900e+04  4.500000e+01     9.100000e+02  1.800000e+01
# max    5.604500e+04  5.600000e+01     1.078329e+06  1.633200e+04
#
#        google_mobility_retail_and_recreation  \
# count                          566919.000000
# mean                              -10.303391
# std                                19.828237
# min                              -100.000000
# 25%                               -21.000000
# 50%                                -9.000000
# 75%                                 2.000000
# ...

# %%
a=np.array(80)
a=list(df.columns)
df[a[70]]

# %%
corr_mat=np.array([77,77])
corr_mat=df.corr()

# %%
a=np.array(77)
a=list(df.columns)
for i in range(77):
    for j in range(77):
        if(corr_mat.iloc[i,j]>0.9):
            print(a[i],",",a[j])
# Out:
# countyFIPS , countyFIPS
# countyFIPS , stateFIPS
# stateFIPS , countyFIPS
# stateFIPS , stateFIPS
# date , date
# confirmed_cases , confirmed_cases
# deaths , deaths
# google_mobility_retail_and_recreation , google_mobility_retail_and_recreation
# google_mobility_grocery_and_pharmacy , google_mobility_grocery_and_pharmacy
# google_mobility_parks , google_mobility_parks
# google_mobility_transit_stations , google_mobility_transit_stations
# google_mobility_workplaces , google_mobility_workplaces
# google_mobility_residential , google_mobility_residential
# apple_mobility_driving , apple_mobility_driving
# apple_mobility_transit , apple_mobility_transit
# apple_mobility_walking , apple_mobility_walking
# apple_mobility_walking , Electricity_Sales_ Revenue_Residential ($ x1000)
# apple_mobility_walking , Electricity_Sales_ Sales_Residential (MWHr)
# apple_mobility_walking , Electricity_Sales_ Customers_Count_Residential
# ...

# %%
df1=df.drop(['Electricity_Sales_ Revenue_Residential ($ x1000)',
 'Electricity_Sales_ Sales_Residential (MWHr)',
 'Electricity_Sales_ Customers_Count_Residential',
 'Electricity_Sales_ Sales_Commercial (MWHr)',
 'Electricity_Sales_ Revenue_Industrial ($ x1000)',
 'Electricity_Sales_ Sales_Industrial (MWHr)',
 'Electricity_Sales_ Customers_Count_Industrial',
 'Electricity_Sales_ Revenue_Transportation ($ x1000)',
 'Electricity_Sales_ Sales_Transportation (MWHr)',
 'Electricity_Sales_ Customers_Count_Transportation',
 'apple_mobility_transit','google_mobility_parks',
 'YoY_Reopened_Seated_Diner_Data','google_mobility_transit_stations',
 'google_mobility_grocery_and_pharmacy',
 'merchants_all_cd',
 'revenue_all_cd','apple_mobility_walking','google_mobility_residential',
 'google_mobility_retail_and_recreation',
 'DOMESTIC_Air_Passengers', 
 'INTERNATIONAL_Air_Passengers',
 'DOMESTIC_Flights_Cnt',
 'INTERNATIONAL_Flights_Cnt'
 ],axis=1)
df1
# Out:
#          countyFIPS  stateFIPS      date  confirmed_cases  deaths  \
# 0              1001          1  22012020                0       0
# 1              1003          1  22012020                0       0
# 2              1005          1  22012020                0       0
# 3              1007          1  22012020                0       0
# 4              1009          1  22012020                0       0
# ...             ...        ...       ...              ...     ...
# 1048570       26105         26  20122020              890      15
# 1048571       26107         26  20122020             1568      12
# 1048572       26109         26  20122020             1571      23
# 1048573       26111         26  20122020             3697      36
# 1048574       26113         26  20122020              405       8
#
#          google_mobility_workplaces  apple_mobility_driving  \
# 0                               NaN                  101.51
# ...

# %%
corr_mat=np.array([77,77])
corr_mat=df.corr()

# %%
a=np.array(77)
a=list(df.columns)
for i in range(77):
    for j in range(77):
        if(corr_mat.iloc[i,j]>0.8):
            print(a[i],",",a[j])
# Out:
# countyFIPS , countyFIPS
# countyFIPS , stateFIPS
# stateFIPS , countyFIPS
# stateFIPS , stateFIPS
# date , date
# date , confirmed_cases
# date , new_test_count
# date , C_PCTPOVALL_2019
# date , C_PCTPOV017_2019
# date , C_PCTPOV517_2019
# date , C_MEDHHINC_2019
# date , C_WA_MALE
# date , C_WA_FEMALE
# confirmed_cases , date
# confirmed_cases , confirmed_cases
# confirmed_cases , C_PCTPOV017_2019
# deaths , deaths
# deaths , google_mobility_retail_and_recreation
# deaths , apple_mobility_driving
# google_mobility_retail_and_recreation , deaths
# google_mobility_retail_and_recreation , google_mobility_retail_and_recreation
# google_mobility_grocery_and_pharmacy , google_mobility_grocery_and_pharmacy
# google_mobility_parks , google_mobility_parks
# google_mobility_parks , apple_mobility_driving
# google_mobility_transit_stations , google_mobility_transit_stations
# google_mobility_workplaces , google_mobility_workplaces
# google_mobility_residential , google_mobility_residential
# ...

# %%
df1.isnull().sum().head(60)
# Out:
# countyFIPS                                                                     0
# stateFIPS                                                                      0
# date                                                                           0
# confirmed_cases                                                                0
# deaths                                                                         0
# google_mobility_workplaces                                                342711
# apple_mobility_driving                                                    422931
# Electricity_Sales_ Revenue_Commercial ($ x1000)                           191845
# Electricity_Sales_ Customers_Count_Commercial                             191845
# test_count                                                                     0
# test_rate                                                                      0
# new_test_rate                                                                  0
# ...

# %%
df2=df1.drop(['C_PCTPOVALL_2019',                                                            
                                                       
'C_PCTPOV517_2019',                                                    
'C_MEDHHINC_2019', 
'C_TOT_MALE',                                                                  
'C_TOT_FEMALE',                                                                
'C_WA_MALE',
'C_WA_FEMALE',
'initclaims_count_regular_cw',                                              
'initclaims_rate_regular_cw', 
'spend_all_cd',                                                             
'critical_staffing_shortage_today_yes_SD',                                    
'previous_day_admission_adult_covid_suspected_SD',
'total_pediatric_patients_hospitalized_confirmed_and_suspected_covid_SD',
'critical_staffing_shortage_today_yes_SD',
'staffed_adult_icu_bed_occupancy_SD', 
'S_D_dly_new_test',
'S_D_cummulative_test'],axis=1)
df2
# Out:
#          countyFIPS  stateFIPS      date  confirmed_cases  deaths  \
# 0              1001          1  22012020                0       0
# 1              1003          1  22012020                0       0
# 2              1005          1  22012020                0       0
# 3              1007          1  22012020                0       0
# 4              1009          1  22012020                0       0
# ...             ...        ...       ...              ...     ...
# 1048570       26105         26  20122020              890      15
# 1048571       26107         26  20122020             1568      12
# 1048572       26109         26  20122020             1571      23
# 1048573       26111         26  20122020             3697      36
# 1048574       26113         26  20122020              405       8
#
#          google_mobility_workplaces  apple_mobility_driving  \
# 0                               NaN                  101.51
# ...

# %%
df2.isnull().sum()
# Out:
# countyFIPS                                                                 0
# stateFIPS                                                                  0
# date                                                                       0
# confirmed_cases                                                            0
# deaths                                                                     0
# google_mobility_workplaces                                            342711
# apple_mobility_driving                                                422931
# Electricity_Sales_ Revenue_Commercial ($ x1000)                       191845
# Electricity_Sales_ Customers_Count_Commercial                         191845
# test_count                                                                 0
# test_rate                                                                  0
# new_test_rate                                                              0
# ...

# %%
df2.corr()
# Out:
#                                                     countyFIPS  stateFIPS  \
# countyFIPS                                            1.000000   0.999075
# stateFIPS                                             0.999075   1.000000
# confirmed_cases                                      -0.038589  -0.038593
# deaths                                               -0.027700  -0.026957
# google_mobility_workplaces                           -0.008129  -0.008087
# apple_mobility_driving                                0.025125   0.025457
# Electricity_Sales_ Revenue_Commercial ($ x1000)       0.062120   0.061637
# Electricity_Sales_ Customers_Count_Commercial         0.120768   0.119946
# C_PCTPOV017_2019                                     -0.074136  -0.075002
# C_TOT_POP                                            -0.054851  -0.054561
# C_MinorityPCT                                        -0.047954  -0.049363
# C_BlackPCT                                           -0.127699  -0.128673
# ...

# %%
b=np.array(1179375)
c=np.array(1179375)
d=np.array(1179375)
e=np.array(1179375)
c1=[1179375]
d1=[1179375]
e1=[1179375]
c=df['countyFIPS']
d=df3['date']
e=df['deaths']
f=[1125]
g=[1125]
h=[1125]
b=df['C_PCTPOV017_2019']

b.isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1179370    False
# 1179371    False
# 1179372    False
# 1179373    False
# 1179374    False
# Name: C_PCTPOV017_2019, Length: 1179375, dtype: bool

# %%
for j in range(1179375):
        if(b[j]== True):
            f.append(c[j])
            g.append(d[j])
            h.append(e[j])
        else:
            c1.append(c[j])
            d1.append(d[j])
            e1.append(e[j])

# %%
b[5]
# Out:
# 39.9

# %%
b.unique()
# Out:
# array([False,  True])

# %%
d1
# Out:
# [1179375,
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200122',
# ...

# %%
g
# Out:
# [1125,
#  '20200122',
#  '20200122',
#  '20200122',
#  '20200123',
#  '20200123',
#  '20200123',
#  '20200124',
#  '20200124',
#  '20200124',
#  '20200125',
#  '20200125',
#  '20200125',
#  '20200126',
#  '20200126',
#  '20200126',
#  '20200127',
#  '20200127',
#  '20200127',
#  '20200128',
#  '20200128',
#  '20200128',
#  '20200129',
#  '20200129',
#  '20200129',
#  '20200130',
#  '20200130',
#  '20200130',
#  '20200131',
#  '20200131',
#  '20200131',
#  '20200201',
#  '20200201',
#  '20200201',
#  '20200202',
#  '20200202',
#  '20200202',
#  '20200203',
#  '20200203',
#  '20200203',
#  '20200204',
#  '20200204',
#  '20200204',
#  '20200205',
#  '20200205',
#  '20200205',
#  '20200206',
#  '20200206',
#  '20200206',
#  '20200207',
#  '20200207',
#  '20200207',
#  '20200208',
#  '20200208',
#  '20200208',
#  '20200209',
#  '20200209',
#  '20200209',
#  '20200210',
#  '20200210',
#  '20200210',
#  '20200211',
#  '20200211',
#  '20200211',
#  '20200212',
#  '20200212',
#  '20200212',
# ...

# %%
df2.dtypes
# Out:
# countyFIPS                                                              int64
# stateFIPS                                                               int64
# date                                                                   object
# confirmed_cases                                                         int64
# deaths                                                                  int64
# google_mobility_workplaces                                            float64
# apple_mobility_driving                                                float64
# Electricity_Sales_ Revenue_Commercial ($ x1000)                       float64
# Electricity_Sales_ Customers_Count_Commercial                         float64
# test_count                                                             object
# test_rate                                                              object
# new_test_rate                                                          object
# ...

# %%
a=np.array(58)
a=list(df2.columns)
a
# Out:
# ['countyFIPS',
#  'stateFIPS',
#  'date',
#  'confirmed_cases',
#  'deaths',
#  'google_mobility_workplaces',
#  'apple_mobility_driving',
#  'Electricity_Sales_ Revenue_Commercial ($ x1000)',
#  'Electricity_Sales_ Customers_Count_Commercial',
#  'test_count',
#  'test_rate',
#  'new_test_rate',
#  'new_test_count',
#  'C_TOT_POP',
#  'C_MinorityPCT',
#  'C_BlackPCT',
#  'C_HispanicPCT',
#  'C_M_Labour_Force_corr',
#  'C_M_Employed_corr',
#  'C_M_Unemployment_Rate_corr',
#  'critical_staffing_shortage_anticipated_within_week_yes_SD',
#  'hospital_onset_covid_SD',
#  'hospital_onset_covid_coverage_SD',
#  'inpatient_beds_SD',
#  'inpatient_beds_coverage_SD',
#  'previous_day_admission_adult_covid_confirmed_SD',
#  'previous_day_admission_pediatric_covid_confirmed_SD',
#  'previous_day_admission_pediatric_covid_suspected_SD',
#  'staffed_adult_icu_bed_occupancy_coverage_SD',
#  'staffed_icu_adult_patients_confirmed_and_suspected_covid_SD',
# ...

# %%
df['S_D_cummulative_test'].corr(df['inpatient_bed_covid_utilization_SD'])
# Out:
# 0.1750265243404717

# %%
df.corr()
# Out:
#                                            countyFIPS  stateFIPS  \
# countyFIPS                                   1.000000   0.999075
# stateFIPS                                    0.999075   1.000000
# confirmed_cases                             -0.038589  -0.038593
# deaths                                      -0.027700  -0.026957
# google_mobility_retail_and_recreation        0.037331   0.037391
# ...                                               ...        ...
# inpatient_beds_utilization_denominator_SD    0.090229   0.089545
# percent_of_inpatients_with_covid_SD         -0.084532  -0.084597
# inpatient_bed_covid_utilization_SD          -0.077226  -0.077261
# adult_icu_bed_covid_utilization_SD          -0.040781  -0.041558
# adult_icu_bed_utilization_SD                -0.015210  -0.015384
#
#                                            confirmed_cases    deaths  \
# countyFIPS                                       -0.038589 -0.027700
# ...

# %%
r=np.array(1)

# %%
def fillin(df,numdays,numstate):
    for i in range(numdays):
        corr_mat=df.iloc[i*numstate: i*(numstate+1) , :].corr()
        df.iloc[i*numstate: i*(numstate+1) , : ]= fillinutil(df.iloc[i*numstate: i*(numstate+1) , : ], corr_mat)
    return df

# %%
def fillinutil(df,corr_mat):
    nullist=[]
    rows=len(list(df.index))
    cols=len(list(df.columns))
    for i in range(rows):
        for j in range(cols):
    
            if(df.iloc[i][j]==None):
                nullist.append([i,j])
    df2=df.copy()
    for i in range(rows):
        for j in range(cols):
            if(df.iloc[i][j]==None):
                df2.iloc[i][j]=0
    npdataset=df2.to_numpy()
    npcorr_mat=corr_mat.to_numpy()
    for i in range(len(nullist)):
        df.iloc[nullist[i][0] , nullist[i][1]]=sum(npdataset[: ,nullist[i][1]] * npcorr_mst[nullist[i][0],nullist[i][1]] )/(len(list(df.index))-df.iloc[:,nullist[i][1]].isnull().to_numpy.sum())
    return df

# %%
df.iloc[5][7]==None
# Out:
# False

# %%
df.dtypes
# Out:
# countyFIPS                                     int64
# stateFIPS                                      int64
# date                                          object
# confirmed_cases                                int64
# deaths                                         int64
#                                               ...
# inpatient_beds_utilization_denominator_SD    float64
# percent_of_inpatients_with_covid_SD          float64
# inpatient_bed_covid_utilization_SD           float64
# adult_icu_bed_covid_utilization_SD           float64
# adult_icu_bed_utilization_SD                 float64
# Length: 82, dtype: object

# %%
df2['date']=df2['date'].apply(pd.to_numeric)

# %%
df2['Electricity_Sales_ Revenue_Commercial ($ x1000)']=df2['Electricity_Sales_ Revenue_Commercial ($ x1000)'].apply(pd.to_numeric)

# %%
df2['Electricity_Sales_ Customers_Count_Commercial']=df2['Electricity_Sales_ Customers_Count_Commercial'].apply(pd.to_numeric)

# %%
df2=df2.replace({'new_test_count':['.']},'0',regex=True)

# %%
df2=df2.replace({'test_count':['.']},'0',regex=True)

# %%
df2=df2.replace({'test_rate':['.']},'0',regex=True)

# %%
df2=df2.replace({'new_test_rate':['.']},'0',regex=True)

# %%
df2['new_test_count']=df2['new_test_count'].apply(pd.to_numeric)

# %%
df2['test_rate']=df2['test_rate'].apply(pd.to_numeric)

# %%
df2['test_count']=df2['test_count'].apply(pd.to_numeric)

# %%
df2['new_test_count']=df2['new_test_count'].apply(pd.to_numeric)

# %%
df2=df2.ffill()
df2['google_mobility_workplaces']=df2['google_mobility_workplaces'].bfill()

# %%
df2.isnull().sum()
# Out:
# countyFIPS                                                            0
# stateFIPS                                                             0
# date                                                                  0
# confirmed_cases                                                       0
# deaths                                                                0
# google_mobility_workplaces                                            0
# apple_mobility_driving                                                0
# Electricity_Sales_ Revenue_Commercial ($ x1000)                       0
# Electricity_Sales_ Customers_Count_Commercial                         0
# test_count                                                            0
# test_rate                                                             0
# new_test_rate                                                         0
# new_test_count                                                        0
# ...

# %%
df3=df2.drop(['confirmed_cases'],axis=1)
df3
# Out:
#          countyFIPS  stateFIPS      date  deaths  google_mobility_workplaces  \
# 0              1001          1  22012020       0                        -4.0
# 1              1003          1  22012020       0                        -4.0
# 2              1005          1  22012020       0                        -4.0
# 3              1007          1  22012020       0                        -4.0
# 4              1009          1  22012020       0                        -4.0
# ...             ...        ...       ...     ...                         ...
# 1048570       26105         26  20122020      15                        -4.0
# 1048571       26107         26  20122020      12                        -8.0
# 1048572       26109         26  20122020      23                        -4.0
# 1048573       26111         26  20122020      36                        -8.0
# 1048574       26113         26  20122020       8                        -8.0
#
#          apple_mobility_driving  \
# ...

# %%
df3.shape
# Out:
# (1048575, 41)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(df3,df2['confirmed_cases'],test_size=0.1,random_state=0)

# %%
from sklearn import linear_model

# %%
Y_train.shape
# Out:
# (943717,)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=1)
X_poly=poly_reg.fit_transform(X_train)
pol_reg=linear_model.LinearRegression()
pol_reg.fit(X_poly,Y_train)
# Out:
# LinearRegression()

# %%
X_test=poly_reg.fit_transform(X_test)
pol_reg.score(X_test,Y_test)
# Out:
# 0.6992493940923749

# %%
X_test.shape
# Out:
# (104858, 41)

# %%
Y_test.shape
# Out:
# (104858,)
